# %%
import cv2
import matplotlib.pyplot as plt

# %%
image = cv2.imread(r"C:\Users\ZAID\Pictures\Guardians Of The Galaxy\screenshot_000003.jpg")

# %%
plt.imshow(image)

# %%
cv2.imshow("ur image", image)
cv2.waitKey()
# Out:
# 27
